# %% [markdown]
# # SCC-DFTB SK-generation
#
# Input: DFTB_DB.db - ASE database with coordinates, energies and forces
#
# Output: Slater-Koster files for each pair of elements stored in ./SKF/
#
#
# Input for the Slater-Koster generation are taken from "$PARAUTOMATIK/pgm/SK_def/skdef.hsd". Modify this file if your elements does'nt exist.

# %%
PARAUTOMATIK_PATH='/Users/tjams20/Documents/repos/ParAutomatik/'   # Add your installation path here

# %%
import os, sys, warnings
import glob
import re
from shutil import copyfile, copytree
import itertools
import numpy as np
from ase.data import atomic_numbers, atomic_names, atomic_masses, covalent_radii, vdw_radii


base_dir=os.getcwd()  # You should be in your production folder now. 
print('Base dir is:', base_dir) 

warnings.filterwarnings('ignore')
sys.path.append("/Users/tjams20/Documents/repos/skprogs-0.1/sktools/build/lib/")
os.system("source /Users/tjams20/Documents/repos/skprogs-0.1/_install/bin/skprogs-activate.sh")

import argparse
import numpy as np
import sktools.common as sc
import sktools.skgen as skgen
from sktools.skdef import Skdef
from sktools import PACKAGE_VERSION
import sk_util
cwd = os.getcwd()
# !source /home/broqvist/Desktop/parautomatik/pgm/skprogs/opt/bin/skprogs-activate.sh should be issued before starting jupyter-lab
skdef_all = PARAUTOMATIK_PATH+'/pgm/SK_def/skdef.hsd'  # parameter file for the data generation
SCRIPTNAME = sc.get_script_name()

# make the directory for the SK-generation and move in to that directory
if not os.path.isdir("SKF/"):
    os.mkdir("SKF/")

os.chdir("SKF/")
print('You are here',os.getcwd())
# Out:
# Base dir is: /Users/tjams20/Documents/repos/ParAutomatik/pgm/Jupyter_notebooks
# You are here /Users/tjams20/Documents/repos/ParAutomatik/pgm/Jupyter_notebooks/SKF

# %%
# automatic search for elements in database
print('You are here',os.getcwd())

import ase.db as db
DFT_DB=db.connect("../DFT_DB.db")
elements=[]
for row in DFT_DB.select():
    structure=row.toatoms()
    a=structure.get_chemical_symbols()
    for i in a: 
        if i not in elements:
            elements.append(i)

elem=''
for i in elements:
    if elem=='':
        elem=i
    else:
        elem=elem+','+i
print(elem)
# Out:
# You are here /Users/tjams20/Documents/repos/ParAutomatik/pgm/Jupyter_notebooks/SKF
# C,H,Li,O

# %%
#set up input for skprogs and run skprogs generating the Slater-Koster files with a dummy rep
parser, subparsers = sk_util.get_parser_and_subparser_container()
sk_util.setup_parser_main(parser)
onecnt_common = sk_util.get_onecnt_common_parser()
sk_util.setup_parser_atom(subparsers, onecnt_common, sk_util.run_atom)
sk_util.setup_parser_denscomp(subparsers, onecnt_common, sk_util.run_denscomp)
sk_util.setup_parser_wavecomp(subparsers, onecnt_common, sk_util.run_wavecomp)
twocnt_common = sk_util.get_twocnt_common_parser()
sk_util.setup_parser_twocnt(subparsers, twocnt_common, sk_util.run_twocnt)
sk_util.setup_parser_sktable(subparsers, twocnt_common, sk_util.run_sktable)

class Args:
    includedirs=[] 
    configfiles=[skdef_all]
    builddir='_build' 
    onecnt_binary='/Users/tjams20/Documents/repos/skprogs-0.1/_install/bin/slateratom' 
    twocnt_binary='/Users/tjams20/Documents/repos/skprogs-0.1/_install/bin/sktwocnt'
    loglevel='info' 
    element1=elem
    element2=elem 
    dummyrep=True 
    outdir='.'
    func=sk_util.run_sktable

        
args=Args()

#run 
args.func()
# Out:
# [ipykernel_launcher.py] Subcommand sktable started
# [skgen.sktable] Started for C-C
# [skgen.sktable] Creating free atom prerequisite for C
# [skgen.atom] Started for C
# [skgen.atom] Calculating spin polarized atom (_build/c/atom.ie2xefp7/atom0_spin)
# [skgen.atom] Calculating spin averaged atom (_build/c/atom.ie2xefp7/atom0)
# [skgen.atom] Calculating Hubbard U values (_build/c/atom.ie2xefp7/hubbu)
# [skgen.atom] Calculating spinw values (_build/c/atom.ie2xefp7/spinw)
# [skgen.atom] Finished
# [skgen.sktable] Creating twocnt prerequisite for C-C
# [skgen.twocnt] Started for C-C
# [skgen.twocnt] Creating compressed atom prerequisite for C
# [skgen.compression] Started for C
# [skgen.compression] Calculating compressed atom (_build/c/comp.wb33eo2o)
# [skgen.compression] Finished
# [skgen.compression] Started for C
# [skgen.compression] Processing compression for shell(s) 2s 2p
# [skgen.compression] Calculating compressed atom (_build/c/comp.yupa6lxr)
# [skgen.compression] Finished
# [skgen.twocnt] Doing twocnt calculation (_build/c-c/twocnt.juyvbi52)
# [skgen.twocnt] Finished
# [skgen.sktable] Finished
# [skgen.sktable] Started for C-H
# [skgen.sktable] Creating free atom prerequisite for C
# [skgen.atom] Started for C
# [skgen.atom] Matching calculation found (_build/c/atom.ie2xefp7)
# [skgen.atom] Finished
# [skgen.sktable] Creating free atom prerequisite for H
# [skgen.atom] Started for H
# [skgen.atom] Calculating spin polarized atom (_build/h/atom.f8319la2/atom0_spin)
# [skgen.atom] Calculating spin averaged atom (_build/h/atom.f8319la2/atom0)
# [skgen.atom] Calculating Hubbard U values (_build/h/atom.f8319la2/hubbu)
# [skgen.atom] Calculating spinw values (_build/h/atom.f8319la2/spinw)
# [skgen.atom] Finished
# [skgen.sktable] Creating twocnt prerequisite for C-H
# [skgen.twocnt] Started for C-H
# [skgen.twocnt] Creating compressed atom prerequisite for C
# [skgen.compression] Started for C
# [skgen.compression] Matching calculation found (_build/c/comp.wb33eo2o)
# [skgen.compression] Finished
# [skgen.compression] Started for C
# [skgen.compression] Processing compression for shell(s) 2s 2p
# [skgen.compression] Matching calculation found (_build/c/comp.yupa6lxr)
# [skgen.compression] Finished
# [skgen.twocnt] Creating compressed atom prerequisite for H
# [skgen.compression] Started for H
# [skgen.compression] Calculating compressed atom (_build/h/comp.8tx7s6dz)
# [skgen.compression] Finished
# [skgen.compression] Started for H
# [skgen.compression] Processing compression for shell(s) 1s
# [skgen.compression] Calculating compressed atom (_build/h/comp.gbmn_tlo)
# [skgen.compression] Finished
# [skgen.twocnt] Doing twocnt calculation (_build/c-h/twocnt.q_kxhplw)
# [skgen.twocnt] Finished
# [skgen.sktable] Finished
# [skgen.sktable] Started for C-Li
# [skgen.sktable] Creating free atom prerequisite for C
# [skgen.atom] Started for C
# [skgen.atom] Matching calculation found (_build/c/atom.ie2xefp7)
# [skgen.atom] Finished
# [skgen.sktable] Creating free atom prerequisite for Li
# [skgen.atom] Started for Li
# [skgen.atom] Calculating spin polarized atom (_build/li/atom.jri5og7a/atom0_spin)
# [skgen.atom] Calculating spin averaged atom (_build/li/atom.jri5og7a/atom0)
# [skgen.atom] Calculating Hubbard U values (_build/li/atom.jri5og7a/hubbu)
# [skgen.atom] Calculating spinw values (_build/li/atom.jri5og7a/spinw)
# [skgen.atom] Finished
# [skgen.sktable] Creating twocnt prerequisite for C-Li
# [skgen.twocnt] Started for C-Li
# [skgen.twocnt] Creating compressed atom prerequisite for C
# [skgen.compression] Started for C
# [skgen.compression] Matching calculation found (_build/c/comp.wb33eo2o)
# [skgen.compression] Finished
# [skgen.compression] Started for C
# [skgen.compression] Processing compression for shell(s) 2s 2p
# [skgen.compression] Matching calculation found (_build/c/comp.yupa6lxr)
# [skgen.compression] Finished
# [skgen.twocnt] Creating compressed atom prerequisite for Li
# [skgen.compression] Started for Li
# [skgen.compression] Calculating compressed atom (_build/li/comp.eqs_uf6d)
# [skgen.compression] Finished
# [skgen.compression] Started for Li
# [skgen.compression] Processing compression for shell(s) 2s 2p
# [skgen.compression] Calculating compressed atom (_build/li/comp.q0k921w3)
# [skgen.compression] Finished
# [skgen.twocnt] Doing twocnt calculation (_build/c-li/twocnt.8ou_tmdy)
# [skgen.twocnt] Finished
# [skgen.sktable] Finished
# [skgen.sktable] Started for C-O
# [skgen.sktable] Creating free atom prerequisite for C
# [skgen.atom] Started for C
# [skgen.atom] Matching calculation found (_build/c/atom.ie2xefp7)
# [skgen.atom] Finished
# [skgen.sktable] Creating free atom prerequisite for O
# [skgen.atom] Started for O
# [skgen.atom] Calculating spin averaged atom (_build/o/atom.32s0hbfm/atom0)
# [skgen.atom] Calculating Hubbard U values (_build/o/atom.32s0hbfm/hubbu)
# [skgen.atom] Calculating spinw values (_build/o/atom.32s0hbfm/spinw)
# [skgen.atom] Finished
# [skgen.sktable] Creating twocnt prerequisite for C-O
# [skgen.twocnt] Started for C-O
# [skgen.twocnt] Creating compressed atom prerequisite for C
# [skgen.compression] Started for C
# [skgen.compression] Matching calculation found (_build/c/comp.wb33eo2o)
# [skgen.compression] Finished
# [skgen.compression] Started for C
# [skgen.compression] Processing compression for shell(s) 2s 2p
# [skgen.compression] Matching calculation found (_build/c/comp.yupa6lxr)
# [skgen.compression] Finished
# [skgen.twocnt] Creating compressed atom prerequisite for O
# [skgen.compression] Started for O
# [skgen.compression] Calculating compressed atom (_build/o/comp.exjzvm27)
# [skgen.compression] Finished
# [skgen.compression] Started for O
# [skgen.compression] Processing compression for shell(s) 2s 2p
# [skgen.compression] Calculating compressed atom (_build/o/comp.h7elxzry)
# [skgen.compression] Finished
# [skgen.twocnt] Doing twocnt calculation (_build/c-o/twocnt.fmbrv7mx)
# [skgen.twocnt] Finished
# [skgen.sktable] Finished
# [skgen.sktable] Started for H-H
# [skgen.sktable] Creating free atom prerequisite for H
# [skgen.atom] Started for H
# [skgen.atom] Matching calculation found (_build/h/atom.f8319la2)
# [skgen.atom] Finished
# [skgen.sktable] Creating twocnt prerequisite for H-H
# [skgen.twocnt] Started for H-H
# [skgen.twocnt] Creating compressed atom prerequisite for H
# [skgen.compression] Started for H
# [skgen.compression] Matching calculation found (_build/h/comp.8tx7s6dz)
# [skgen.compression] Finished
# [skgen.compression] Started for H
# [skgen.compression] Processing compression for shell(s) 1s
# [skgen.compression] Matching calculation found (_build/h/comp.gbmn_tlo)
# [skgen.compression] Finished
# [skgen.twocnt] Doing twocnt calculation (_build/h-h/twocnt.8uusn61g)
# [skgen.twocnt] Finished
# [skgen.sktable] Finished
# [skgen.sktable] Started for H-Li
# [skgen.sktable] Creating free atom prerequisite for H
# [skgen.atom] Started for H
# [skgen.atom] Matching calculation found (_build/h/atom.f8319la2)
# [skgen.atom] Finished
# [skgen.sktable] Creating free atom prerequisite for Li
# [skgen.atom] Started for Li
# [skgen.atom] Matching calculation found (_build/li/atom.jri5og7a)
# [skgen.atom] Finished
# [skgen.sktable] Creating twocnt prerequisite for H-Li
# [skgen.twocnt] Started for H-Li
# [skgen.twocnt] Creating compressed atom prerequisite for H
# [skgen.compression] Started for H
# [skgen.compression] Matching calculation found (_build/h/comp.8tx7s6dz)
# [skgen.compression] Finished
# [skgen.compression] Started for H
# [skgen.compression] Processing compression for shell(s) 1s
# [skgen.compression] Matching calculation found (_build/h/comp.gbmn_tlo)
# [skgen.compression] Finished
# [skgen.twocnt] Creating compressed atom prerequisite for Li
# [skgen.compression] Started for Li
# [skgen.compression] Matching calculation found (_build/li/comp.eqs_uf6d)
# [skgen.compression] Finished
# [skgen.compression] Started for Li
# [skgen.compression] Processing compression for shell(s) 2s 2p
# [skgen.compression] Matching calculation found (_build/li/comp.q0k921w3)
# [skgen.compression] Finished
# [skgen.twocnt] Doing twocnt calculation (_build/h-li/twocnt.fxhvt_o2)
# [skgen.twocnt] Finished
# [skgen.sktable] Finished
# [skgen.sktable] Started for H-O
# [skgen.sktable] Creating free atom prerequisite for H
# [skgen.atom] Started for H
# [skgen.atom] Matching calculation found (_build/h/atom.f8319la2)
# [skgen.atom] Finished
# [skgen.sktable] Creating free atom prerequisite for O
# [skgen.atom] Started for O
# [skgen.atom] Matching calculation found (_build/o/atom.32s0hbfm)
# [skgen.atom] Finished
# [skgen.sktable] Creating twocnt prerequisite for H-O
# [skgen.twocnt] Started for H-O
# [skgen.twocnt] Creating compressed atom prerequisite for H
# [skgen.compression] Started for H
# [skgen.compression] Matching calculation found (_build/h/comp.8tx7s6dz)
# [skgen.compression] Finished
# [skgen.compression] Started for H
# [skgen.compression] Processing compression for shell(s) 1s
# [skgen.compression] Matching calculation found (_build/h/comp.gbmn_tlo)
# [skgen.compression] Finished
# [skgen.twocnt] Creating compressed atom prerequisite for O
# [skgen.compression] Started for O
# [skgen.compression] Matching calculation found (_build/o/comp.exjzvm27)
# [skgen.compression] Finished
# [skgen.compression] Started for O
# [skgen.compression] Processing compression for shell(s) 2s 2p
# [skgen.compression] Matching calculation found (_build/o/comp.h7elxzry)
# [skgen.compression] Finished
# [skgen.twocnt] Doing twocnt calculation (_build/h-o/twocnt.gdm8mqtq)
# [skgen.twocnt] Finished
# [skgen.sktable] Finished
# [skgen.sktable] Started for Li-Li
# [skgen.sktable] Creating free atom prerequisite for Li
# [skgen.atom] Started for Li
# [skgen.atom] Matching calculation found (_build/li/atom.jri5og7a)
# [skgen.atom] Finished
# [skgen.sktable] Creating twocnt prerequisite for Li-Li
# [skgen.twocnt] Started for Li-Li
# [skgen.twocnt] Creating compressed atom prerequisite for Li
# [skgen.compression] Started for Li
# [skgen.compression] Matching calculation found (_build/li/comp.eqs_uf6d)
# [skgen.compression] Finished
# [skgen.compression] Started for Li
# [skgen.compression] Processing compression for shell(s) 2s 2p
# [skgen.compression] Matching calculation found (_build/li/comp.q0k921w3)
# [skgen.compression] Finished
# [skgen.twocnt] Doing twocnt calculation (_build/li-li/twocnt.m3a73tqd)
# [skgen.twocnt] Finished
# [skgen.sktable] Finished
# [skgen.sktable] Started for Li-O
# [skgen.sktable] Creating free atom prerequisite for Li
# [skgen.atom] Started for Li
# [skgen.atom] Matching calculation found (_build/li/atom.jri5og7a)
# [skgen.atom] Finished
# [skgen.sktable] Creating free atom prerequisite for O
# [skgen.atom] Started for O
# [skgen.atom] Matching calculation found (_build/o/atom.32s0hbfm)
# [skgen.atom] Finished
# [skgen.sktable] Creating twocnt prerequisite for Li-O
# [skgen.twocnt] Started for Li-O
# [skgen.twocnt] Creating compressed atom prerequisite for Li
# [skgen.compression] Started for Li
# [skgen.compression] Matching calculation found (_build/li/comp.eqs_uf6d)
# [skgen.compression] Finished
# [skgen.compression] Started for Li
# [skgen.compression] Processing compression for shell(s) 2s 2p
# [skgen.compression] Matching calculation found (_build/li/comp.q0k921w3)
# [skgen.compression] Finished
# [skgen.twocnt] Creating compressed atom prerequisite for O
# [skgen.compression] Started for O
# [skgen.compression] Matching calculation found (_build/o/comp.exjzvm27)
# [skgen.compression] Finished
# [skgen.compression] Started for O
# [skgen.compression] Processing compression for shell(s) 2s 2p
# [skgen.compression] Matching calculation found (_build/o/comp.h7elxzry)
# [skgen.compression] Finished
# [skgen.twocnt] Doing twocnt calculation (_build/li-o/twocnt.qzc1uf9d)
# [skgen.twocnt] Finished
# [skgen.sktable] Finished
# [skgen.sktable] Started for O-O
# [skgen.sktable] Creating free atom prerequisite for O
# [skgen.atom] Started for O
# [skgen.atom] Matching calculation found (_build/o/atom.32s0hbfm)
# [skgen.atom] Finished
# [skgen.sktable] Creating twocnt prerequisite for O-O
# [skgen.twocnt] Started for O-O
# [skgen.twocnt] Creating compressed atom prerequisite for O
# [skgen.compression] Started for O
# [skgen.compression] Matching calculation found (_build/o/comp.exjzvm27)
# [skgen.compression] Finished
# [skgen.compression] Started for O
# [skgen.compression] Processing compression for shell(s) 2s 2p
# [skgen.compression] Matching calculation found (_build/o/comp.h7elxzry)
# [skgen.compression] Finished
# [skgen.twocnt] Doing twocnt calculation (_build/o-o/twocnt.ohow87jp)
# [skgen.twocnt] Finished
# [skgen.sktable] Finished
# [ipykernel_launcher.py] Directory with assembled SK-file(s): .
# [ipykernel_launcher.py] SK-file(s) written: C-C.skf C-H.skf H-C.skf C-Li.skf Li-C.skf C-O.skf O-C.skf H-H.skf H-Li.skf Li-H.skf H-O.skf O-H.skf Li-Li.skf Li-O.skf O-Li.skf O-O.skf
